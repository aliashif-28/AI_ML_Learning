# %%
import numpy as np

# %%
a = np.array([[2,3,4],[3,5,6],[5,8,9],[6,9,11],[7,10,13]])
a
# Out:
# array([[ 2,  3,  4],
#        [ 3,  5,  6],
#        [ 5,  8,  9],
#        [ 6,  9, 11],
#        [ 7, 10, 13]])

# %%
mean_x=np.mean(a,axis=0)
mean_x
# Out:
# array([4.6, 7. , 8.6])

# %%
x_center = a - mean_x
x_center
# Out:
# array([[-2.6, -4. , -4.6],
#        [-1.6, -2. , -2.6],
#        [ 0.4,  1. ,  0.4],
#        [ 1.4,  2. ,  2.4],
#        [ 2.4,  3. ,  4.4]])

# %%
cov_matrix = np.cov(x_center,rowvar=False)
cov_matrix
# Out:
# array([[ 4.3 ,  6.  ,  7.55],
#        [ 6.  ,  8.5 , 10.5 ],
#        [ 7.55, 10.5 , 13.3 ]])

# %%
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)
eigenvalues
# Out:
# array([2.59637803e+01, 5.52557327e-03, 1.30694106e-01])

# %%
eigenvectors
# Out:
# array([[ 0.4066816 ,  0.90812885,  0.09955937],
#        [ 0.56930735, -0.16669075, -0.80504865],
#        [ 0.71449228, -0.38407836,  0.58479449]])

# %%
sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:,sorted_indices]

# %%
x_transformed_1 = x_center @ eigenvectors[:,0]

# %%
x_transformed_2 = x_center @ eigenvectors[:,:2]

# %%
print(f"1. Transformed Data(3 to 1)P:-\n\n -->  {x_transformed_1}\n\n")
print(f"2. Transformed Data(3 to 2)P:-\n\n --> \n{x_transformed_2}")
# Out:
# 1. Transformed Data(3 to 1)P:-
#
#  -->  [-6.62126605 -3.64698519  1.0177769   3.42275041  5.82772392]
#
#
# 2. Transformed Data(3 to 2)P:-
#
#  -->
# [[-6.62126605  0.27128556]
#  [-3.64698519 -0.06966338]
#  [ 1.0177769  -0.5313071 ]
#  [ 3.42275041 -0.0672074 ]
#  [ 5.82772392  0.39689231]]

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('C:\AI_ML\winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1591            6.2             0.600         0.08             2.0      0.090
# 1592            5.9             0.550         0.10             2.2      0.062
# 1593            6.3             0.510         0.13             2.3      0.076
# 1594            5.9             0.645         0.12             2.0      0.075
# 1595            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1591            6.2             0.600         0.08             2.0      0.090
# 1592            5.9             0.550         0.10             2.2      0.062
# 1593            6.3             0.510         0.13             2.3      0.076
# 1594            5.9             0.645         0.12             2.0      0.075
# 1595            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1591                 32.0                  44.0  0.99490  3.45       0.58
# 1592                 39.0                  51.0  0.99512  3.52       0.76
# 1593                 29.0                  40.0  0.99574  3.42       0.75
# 1594                 32.0                  44.0  0.99547  3.57       0.71
# 1595                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1591     10.5        5
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1596.000000       1596.000000  1596.000000     1596.000000
# mean        8.314160          0.527954     0.270276        2.535558
# std         1.732203          0.179176     0.193894        1.405515
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.600000          1.580000     0.790000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1596.000000          1596.000000           1596.000000  1596.000000
# mean      0.087120            15.858396             46.382206     0.996744
# std       0.045251            10.460554             32.839138     0.001888
# ...

# %%
df.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1591          False             False        False           False      False
# 1592          False             False        False           False      False
# 1593          False             False        False           False      False
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
#
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_train)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=7)
x_train = pca.fit_transform(x_train)

# %%
x_test = pca.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression 
model = LogisticRegression(random_state = 0)
model.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
y_pred = model.predict(x_test)
y_pred
# Out:
# array([3, 8, 3, ..., 8, 8, 3], shape=(1276,))

# %%
matrix = confusion_matrix(y_test,y_pred)
print("matrix")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 matrix = confusion_matrix(y_test,y_pred)
#       2 print("matrix")
#
# File c:\Users\alias\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
# ...
