# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# c:\Users\alias\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
data = pd.read_csv("users.csv")

# %%
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   12            19000          0
# 1  15810944    Male   11            20000          0
# 2  15668575  Female    1            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   10            76000          0

# %%
data["Gender"].unique()
# Out:
# <ArrowStringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
data["Purchased"].unique()
# Out:
# array([0, 1])

# %%
x = data.columns.drop("Purchased")
y = data["Purchased"]

# %%
data_encoded = pd.get_dummies(data[x].astype(int))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data_encoded = pd.get_dummies(data[x].astype(int))
#
# File c:\Users\alias\anaconda3\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File c:\Users\alias\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File c:\Users\alias\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File c:\Users\alias\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File c:\Users\alias\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File c:\Users\alias\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     178     return values
#     180 if not isinstance(values, np.ndarray):
#     181     # i.e. ExtensionArray
# --> 182     values = values.astype(dtype, copy=copy)
#     184 else:
#     185     values = _astype_nansafe(values, dtype, copy=copy)
#
# File c:\Users\alias\anaconda3\Lib\site-packages\pandas\core\arrays\string_arrow.py:330, in ArrowStringArray.astype(self, dtype, copy)
#     327 elif isinstance(dtype, np.dtype) and np.issubdtype(dtype, np.floating):
#     328     return self.to_numpy(dtype=dtype, na_value=np.nan)
# --> 330 return super().astype(dtype, copy=copy)
#
# File c:\Users\alias\anaconda3\Lib\site-packages\pandas\core\arrays\base.py:829, in ExtensionArray.astype(self, dtype, copy)
#     826     return TimedeltaArray._from_sequence(self, dtype=dtype, copy=copy)
#     828 if not copy:
# --> 829     return np.asarray(self, dtype=dtype)
#     830 else:
#     831     return np.array(self, dtype=dtype, copy=copy)
#
# File c:\Users\alias\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py:862, in ArrowExtensionArray.__array__(self, dtype, copy)
#     858 elif copy is None:
#     859     # `to_numpy(copy=False)` has the meaning of NumPy `copy=None`.
#     860     copy = False
# --> 862 return self.to_numpy(dtype=dtype, copy=copy)
#
# File c:\Users\alias\anaconda3\Lib\site-packages\pandas\core\arrays\arrow\array.py:1713, in ArrowExtensionArray.to_numpy(self, dtype, copy, na_value)
#    1711 result = data._pa_array.to_numpy()
#    1712 if dtype is not None:
# -> 1713     result = result.astype(dtype, copy=False)
#    1714 if copy:
#    1715     result = result.copy()
#
# ValueError: invalid literal for int() with base 10: 'Male'

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(criterion="gini",random_state=1)

# %%
dooing a train  test code
